# %%
import numpy as np
import matplotlib.pyplot as plt
from Utils import *

# %%
X, y = Dataset(mode="NL", dist="Circular", num_points=1000, r1=1, r2=2, frac=0.5, noise_mag = 0.1).get_data()
# Out:
# (500, 2)
# (500, 1)

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
hc = HingeClassifier(X, y)
hc.X.shape
hc.y.shape
hc.train(epochs=1, lr=0.01)
# Out:
# (array([-1.04      ,  0.00604984,  0.00245721]), 312)

# %%
binary_accuracy(hc, X, y)
# Out:
# 0.5

# %%
z = plot_contour(hc, X, y, "Hinge Classifier")
# Out:
# /home/arkartik/IITH-courses/AI5000/AI500-Deep-Learning/A1/Utils/utility.py:32: UserWarning: No contour levels were found within the data range.
#   plt.contour(xx, yy, z.reshape(xx.shape), [-1,0,1], colors='k')

# %%
z.shape
# Out:
# (101440,)

# %%
X, y = Dataset(mode="L", num_points=1000, frac=0.5, separability= 2, bias=20, noise_mag = 0.1, w_1=[1,1]).get_data()

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
hc = HingeClassifier(X, y)
weights,corr_count = hc.train(epochs=10, lr=0.1)

# %%
binary_accuracy(hc, X, y)
# Out:
# 1.0

# %%
plot_contour(hc, X, y, "Hinge Classifier")
# Out:
# array([-7.26647068, -7.2509996 , -7.23552852, ...,  9.41837459,
#         9.43384567,  9.44931675])
