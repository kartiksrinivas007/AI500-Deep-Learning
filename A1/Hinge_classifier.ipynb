# %%
import numpy as np
import matplotlib.pyplot as plt
from Utils import *

# %%
X, y = Dataset(mode="NL", dist="Circular", num_points=1000, r1=1, r2=2, frac=0.5).get_data()
# Out:
# (500, 2)
# (500, 1)

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
plt.scatter(X[:,0], X[:,1], c=y)
