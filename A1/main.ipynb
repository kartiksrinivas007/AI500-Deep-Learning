# %%
import numpy as np
import matplotlib.pyplot as plt
from Utils import *

# %%
X, y = Dataset(1000, n_dim=2, mode="L", w_1=np.array([1,2]), separability=2, bias = 30).get_data()

# %%
X.shape
# Out:
# (1000, 2)

# %%
y.shape
# Out:
# (1000,)

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
np.where(y == -1)
# Out:
# (array([  1,   2,   3,   6,   7,  10,  12,  13,  15,  17,  18,  21,  24,
#          25,  26,  28,  30,  33,  34,  36,  37,  38,  39,  42,  43,  44,
#          47,  49,  54,  56,  57,  58,  60,  61,  62,  71,  72,  73,  75,
#          78,  79,  82,  84,  86,  87,  88,  90,  91,  92,  94,  95,  96,
#         100, 101, 103, 107, 109, 110, 111, 115, 117, 121, 124, 126, 128,
#         132, 133, 134, 135, 138, 140, 142, 145, 147, 148, 152, 154, 156,
#         160, 162, 163, 164, 165, 166, 167, 168, 173, 177, 178, 180, 182,
#         187, 193, 194, 195, 197, 198, 199, 201, 202, 203, 204, 205, 206,
#         209, 210, 213, 214, 215, 216, 220, 221, 223, 225, 226, 228, 229,
#         232, 233, 234, 235, 236, 237, 238, 239, 240, 244, 245, 246, 247,
#         248, 250, 255, 258, 261, 266, 267, 268, 270, 271, 273, 276, 277,
#         279, 282, 283, 285, 289, 293, 295, 296, 300, 302, 306, 309, 312,
#         313, 314, 317, 322, 324, 328, 330, 332, 335, 336, 339, 340, 341,
# ...

# %%
p = Perceptron(X, y)
weights,corr_count = p.train()

# %%
corr_count
# Out:
# 1212

# %%
binary_accuracy(p, X, y)
# Out:
# 1.0

# %%
plot_mesh_advanced(p, X, y, "Perceptron")

# %%
plot_contour(p, X, y, "Perceptron")
